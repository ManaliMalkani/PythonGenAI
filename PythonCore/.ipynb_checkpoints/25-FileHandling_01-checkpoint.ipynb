# %% [markdown]
# -----------------
# ## File handling
# -------------------
# - in a large software application where they process a large number of data, then we cannot expect those data to be stored in a variable.
#
# - As files are written in data, are stored permanently and using python we will handle these files in our applications.
#
# #### Types Of File in Python
# There are 2 types of files in Python and each of them are explained below in detail with examples for your easy understanding.
#
# - Binary file
# - Text file
#
# 1. `Binary files` in Python - Most of the files that we see in our computer system are called binary files.
#
#     - Document files: .pdf, .doc, .xls etc.
#     - Image files: .png, .jpg, .gif, .bmp etc.
#     - Video files: .mp4, .3gp, .mkv, .avi etc.
#     - Audio files: .mp3, .wav, .mka, .aac etc.
#     - Database files: .mdb, .accde, .frm, .sqlite etc.
#     - Archive files: .zip, .rar, .iso, .7z etc.
#     - Executable files: .exe, .dll, .class etc.
#
# All binary files follow a `specific format`. We can open some binary files in the normal text editor but we can’t read the content present inside the file. That’s because all the binary files will be `encoded` in the binary format
#
# > For handling such binary files we need a specific type of software to open it.
#
# 2. `Text files` in Python
# - Text files don’t have any specific encoding and it can be opened in normal text editor itself.
#
#     - Web standards: html, XML, CSS, JSON etc.
#     - Source code: c, app, js, py, java etc.
#     - Documents: txt, tex, RTF etc.
#     - Tabular data: csv, tsv etc.
#     - Configuration: ini, cfg, reg etc.
#
# 3. Python File Handling Operations
# - Most importantly there are 4 types of operations that can be handled by Python on files:
#
#     - Open
#     - Read
#     - Write
#     - Close
#
# - Other operations include:
#
#     - Rename
#     - Delete

# %% [markdown]
# --------
# #### Create and Open a File
# -------
#
# **Syntax:**
#
#     file_object = open(file_name, `mode`)
#
# The `mode` in the open function syntax will tell Python as what operation we want to do on a file.
#
# - For text file
#
#     - ‘r’ – Read Mode: Read mode is used only to read data from the file.
#     - ‘w’ – Write Mode: This mode is used when you want to write data into the file or modify it. Remember write mode overwrites the data present in the file.
#     - ‘a’ – Append Mode: Append mode is used to append data to the file. Remember data will be appended at the end of the file pointer.
#     - ‘r+’ – Read or Write Mode: This mode is used when we want to write or read the data from the same file.
#     - ‘a+’ – Append or Read Mode: This mode is used when we want to read data from the file or append the data into the same file.
#
# > Note: The above-mentioned modes are for opening, reading or writing `text files only`.
#
# - While using `binary files`, we have to use the same modes with the letter ‘b’ at the end. So that Python can understand that we are interacting with binary files.
#
#     - ‘wb’ – Open a file for write only mode in the binary format.
#     - ‘rb’ – Open a file for the read-only mode in the binary format.
#     - ‘ab’ – Open a file for appending only mode in the binary format.
#     - ‘rb+’ – Open a file for read and write only mode in the binary format.
#     - ‘ab+’ – Open a file for appending and read-only mode in the binary format.

# %% [markdown]
# **Example 1:** - open a text file in read-write mode

# %% [markdown]
# fo = open('file_handling.txt', 'r+')

# %% [markdown]
# **Example 2:** - open a PNG file in binary mode

# %%
fo = open('Images/dict_00.png', 'rb+')

# %% [markdown]
# --------------------
# #### Read From File
# ----------------------
# - In order to read a file in python, we must open the file in `read` mode.
#
# - There are 3 ways in which we can read the files in python.
#
#     - read([n])
#     - readline([n])
#     - readlines()
#
# Here, n is the number of bytes to be read.

# %%
my_file = open('file_handling.txt', 'r')

print(my_file.read(50))
# Out:
# Manali
# Malkani
# Amaira
# Bhardwaj
# Ankit
# Arnika
# Atharv

# %% [markdown]
# reads first 5 chars

# %%
print(my_file.read())

# %% [markdown]
# starts reading from the above read position in the text file

# %%
my_file = open('file_handling.txt', 'r')

print(my_file.read())
# Out:
# Manali
# Malkani
# Amaira
# Bhardwaj
# Ankit
# Arnika
# Atharv

# %% [raw]
# Here we have not provided any argument inside the read() function. Hence it will `read all the content` present inside the file.

# %% [markdown]
# **Example 4:**

# %%
my_file = open('file_handling.txt', 'r')

print(my_file.readlines())
# Out:
# ['Manali\n', 'Malkani\n', 'Amaira\n', 'Bhardwaj\n', 'Ankit\n', 'Arnika\n', 'Atharv']

# %% [markdown]
# This function returns the `first 2 characters` of the next line.

# %%
my_file = open('file_handling.txt', 'r')

print(my_file.readline())
# Out:
# Manali

# %% [markdown]
# **reads line by line**

# %%
my_file = open('file_handling.txt', 'r')

for line in my_file:
    print(line)
# Out:
# Manali
#
# Malkani
#
# Amaira
#
# Bhardwaj
#
# Ankit
#
# Arnika
#
# Atharv

# %% [markdown]
# **read all the lines**

# %%
# Open a file
my_file = open('file_handling.txt', 'r')

lines = my_file.readlines()

print ('number of lines : ', len(lines))

for line in lines:
    print(line)

# Close opend file
my_file.close()
# Out:
# number of lines :  7
# Manali
#
# Malkani
#
# Amaira
#
# Bhardwaj
#
# Ankit
#
# Arnika
#
# Atharv

# %% [markdown]
# **Example : 5** - Reading a specific line from a File

# %%
line_number = 5

my_file = open('file_handling.txt', 'r')

currentLine = 1

for line in my_file:
    if(currentLine == line_number):
        print(line)
        break

    currentLine = currentLine+ 1
# Out:
# Ankit

# %% [markdown]
# **Example: 6**

# %%
with open('file_handling.txt', 'r') as f:
    lines = [line.rstrip() for line in f]

print(lines)
# Out:
# ['Manali', 'Malkani', 'Amaira', 'Bhardwaj', 'Ankit', 'Arnika', 'Atharv']

# %%
len(lines)
# Out:
# 7

# %%
with open('file_handling.txt', 'r') as f:
    content = f.read().splitlines()

print(content)
# Out:
# ['Manali', 'Malkani', 'Amaira', 'Bhardwaj', 'Ankit', 'Arnika', 'Atharv']

# %% [markdown]
# -------------------
# #### `Image` file handling
# -------------------

# %%
from PIL import Image, ImageDraw, ImageFont 
from IPython.display import display

import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

# %%
location1 = 'Images/ML-eval-06.JPG'
location2 = 'Images/NLP-topic-model-analysis-00.JPG'

# %%
im1 = Image.open(location1)
im2 = Image.open(location2)

# %% [markdown]
# #### properties of the image

# %% [markdown]
# - The __format__ attribute identifies the source of an image. If the image was not read from a file, it is set to None.
#
# - The __size__ attribute is a 2-tuple containing width and height (in pixels).
#
# - The __mode__ attribute defines the number and names of the bands in the image, and also the pixel type and depth. Common modes are
#     - “L” (luminance) for greyscale images,
#     - “RGB” for true color images, and
#     - “CMYK” for pre-press images.

# %%
im1.format, im1.size, im1.mode
# Out:
# ('JPEG', (1116, 481), 'RGB')

# %%
im2.format, im2.size, im2.mode
# Out:
# ('JPEG', (812, 538), 'RGB')

# %% [markdown]
# #### displaying

# %%
im1.show()

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(6,3))

# %%
plt.figure(figsize=(12, 5))

# Defines the first subplot in a 1-row, 2-column grid (denoted by "12"). 121 means it's the 1st subplot in the grid.

plt.subplot(121)
plt.imshow(im1)

# Defines the second subplot in the 1-row, 2-column grid (denoted by "12").122 means it's the 2nd subplot in the grid.
plt.subplot(122)
plt.imshow(im2);

# %%
display(im1)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1116x481>

# %% [markdown]
# #### saving

# %%
im1.save('im_saved.jpg')

# %% [markdown]
# #### cropping

# %%
box    = (100, 100, 400, 400)
region = im1.crop(box)

# %% [markdown]
# The region is defined by a 4-tuple, where coordinates are (left, upper, right, lower).
#
# The Python Imaging Library uses a coordinate system with (0, 0) in the __upper left corner__.
#
# Also note that coordinates refer to positions between the pixels, so the region in the above example is exactly 300x300 pixels.

# %%
plt.imshow(region);

# %%
im1_copy = im1.copy()
plt.imshow(im1_copy);

# %% [markdown]
# #### transposing

# %%
out = im1.transpose(Image.FLIP_LEFT_RIGHT)
out = im1.transpose(Image.FLIP_TOP_BOTTOM)
out = im1.transpose(Image.ROTATE_90)
out = im1.transpose(Image.ROTATE_180)
out = im1.transpose(Image.ROTATE_270)
plt.imshow(out)

# %% [markdown]
# ----------------------
# #### `Audio` file handling
# ----------------------------

# %% [markdown]
# #### Example 1

# %%
# listen to all the mp3 files in order
import os

folder=os.listdir(r'Audio')
print(folder)
# Out:
# ['IMG_0773.jpg', 'audio[183938].mp3', 'IMG_0773 (1).jpg', 'test.wav', 'QR code.JPG', 'IMG_20200129_164711_1.jpg', 'audio[185424].mp3']

# %%
# Only for windows
for file in folder:
    if file.endswith(".mp3"):
        file_path = 'Audio'+file
        #os.startfile(file_path)

# %%
import os
import subprocess

# Path to the folder containing MP3 files
folder = os.listdir('Audio')
print(folder)

for file in folder:
    if file.endswith(".mp3"):
        file_path = os.path.join('Audio', file)  # Construct the full file path
        try:
            # Use subprocess to open the file
            if os.name == 'nt':  # Windows
                os.startfile(file_path)
            elif os.name == 'posix':  # macOS/Linux
                subprocess.run(['open', file_path] if sys.platform == 'darwin' else ['xdg-open', file_path])
        except Exception as e:
            print(f"Error opening {file}: {e}")
# Out:
# ['IMG_0773.jpg', 'audio[183938].mp3', 'IMG_0773 (1).jpg', 'test.wav', 'QR code.JPG', 'IMG_20200129_164711_1.jpg', 'audio[185424].mp3']

# %% [markdown]
# #### Example 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io.wavfile import read, write
from IPython.display import Audio
from numpy.fft import fft, ifft
# %matplotlib inline

# %% [markdown]
# ## Read Audio Input

# %% [markdown]
# You can use scipy.io.wavefile to read and write a wav file.
# Usually audio file contains two channels (left and right). We will only keep one channel for simplicity. In the code below, "data = data[:,0]" will keep channel 0.

# %%
Fs, data = read(r'Audio/test.wav')

data = data[:,0]

print("Sampling Frequency is", Fs)
# Out:
# Sampling Frequency is 48000

# %% [markdown]
# ## Play Audio

# %% [markdown]
# You can use IPython.display.Audio to play audio.

# %%
Audio(data, rate=Fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Plot the wave

# %% [markdown]
# We use matplotlib.pyplot to plot the signal. To produce a plot between cells in Jupyter Notebook, you need to add "%matplotlib inline"

# %%
plt.figure()
plt.plot(data)
plt.xlabel('Sample Index')
plt.ylabel('Amplitude')
plt.title('Waveform of Test Audio')
plt.show()

# %% [markdown]
# ## Write Audio File

# %%
write('Images/output.wav', Fs, data)

# %% [markdown]
# --------------------
# #### Working with PDF files in Python
# ------------------
#
# - We will be using a third-party module, `PyPDF2.
#
# - `PyPDF2` is a python library built as a PDF toolkit. It is capable of:
#
#     - Extracting document information (title, author, …)
#     - Splitting documents page by page
#     - Merging documents page by page
#     - Cropping pages
#     - Merging multiple pages into a single page
#     - Encrypting and decrypting PDF files
#         - and more!
#
# - To install PyPDF2, run following command from command line:
#
# `pip install PyPDF2`

# %%
# !pip install PyPDF2
# Out:
# Requirement already satisfied: PyPDF2 in /opt/anaconda3/lib/python3.12/site-packages (3.0.1)

# %% [markdown]
# #### Extracting text from PDF

# %%
# importing required modules 
import PyPDF2 

from PyPDF2 import PdfReader

# creating a pdf file object 
pdfFileObj = open(r'pdf/ManaliMalkaniResume.pdf', 'rb') 

# creating a pdf reader object 
# Here, we create an object of PdfReader class of PyPDF2 module and  
# pass the pdf file object & get a pdf reader object.
pdfReader = PdfReader(pdfFileObj)

# printing number of pages in pdf file 
# Accessing the number of pages (optional example)
print(f"Number of pages: {len(pdfReader.pages)}")

# creating a page object 
# Now, we create an object of PageObject class of PyPDF2 module. 
# pdf reader object has function getPage() which takes page number (starting form index 0) as 
# argument and returns the page object.
page_number = 0  # Page numbers start at 0
first_page = pdfReader.pages[page_number]

# Extract text from the page
print(first_page.extract_text())

pdfFileObj.close()
# Out:
# incorrect startxref pointer(3)
# Number of pages: 2
# +971552469689
# manalimalkani@gmail.com
# SUMMARY
# Innovative individual with proven
# success evaluating requirements
# for software development projects
# to design innovative solutions.
# Out-of-the-box thinker and problem
# solver dedicated to improving
# performance. Works well in teams
# and consistently delivers to
# deadlines.
# SKILLS
# 13 Years of Experience in
# Software Testing•
# Extensive experience in Mobile
# Automation Testing, Web
# Automation Testing, Functional
# Database Testing, API Testing
# and Automation, ETL Testing,
# Report Testing, Smoke Testing,
# Localization testing, Sanity
# Testing, Exploratory Testing,
# Compatibility Testing, SIT
# Testing, Regression Testing and
# UAT Testing•
# Experience in CI/CD Tools like
# Docker, Jenkins, Git, GitHub.•
# Well versed in DevOps, Agile,
# SDLC, STLC, Scrum, Kanban
# and Waterfall.•
# Worked on BDD, Hybrid, Data
# Driven and Keyword framework.•
# Managing and leading test
# teams, coordination activities
# between multiple teams•
# Automation Testing
# Tools (Selenium, Selenium Grid
# ,Robert Framework with•Manali Malkani
# EXPERIENCE
# October 2020  - Current
# QA Lead Majid Al Futtaim Carrefour
# March 2018  - September 2020
# SDET Emirates AirlinesCreated automated test scripts that reduced regression testing time
# by 50%, boosting overall testing efficiency.•
# Spearheaded a defect reduction initiative, resulting in a 30%
# decrease in critical post-deployment issues and improved system
# stability.•
# Develop testing strategies specific to machine learning (ML)
# pipelines, including data ingestion, preprocessing, model training,
# and inference.•
# Validate the quality, consistency, and integrity of input datasets,
# ensuring they meet the requirements for model training and
# predictions.•
# We utilized a BDD & TDD Flutter Gherkin framework for front-end
# testing and implemented a Postman API automation strategy for
# back-end API testing•
# Utilized flutter's integration_test for automating the UI flutter based
# mobile application. Have hands on experience in using proxyman for
# proxy and mocking purpose.•
# Utilized robert framework and appium for automation.•
# Demonstrated expertise in building and maintaining UI and API
# automation frameworks while leading QA teams across various
# products, driving the implementation of new tools and
# methodologies to enhance software quality.•
# Proficient in multiple programming languages, testing frameworks,
# and CI/CD tools, with a strong commitment to delivering high-quality
# software solutions.•
# Led QA initiatives for data analytics projects, ensuring the accuracy,
# reliability, and performance of solutions.•
# Successfully launched Carrefour City Plus (AI Based Store) and
# Scan & Go projects across the Middle East, improving customer
# experience and operational efficiency.•
# Oversaw AI testing initiatives in e-commerce, focusing on
# recommendation systems and predictive analytics.•
# Conducted thorough data validation testing across diverse data
# sources to ensure accuracy and consistency in AI-driven insights.•
# Collaborated closely with data scientists and AI engineers,
# developing targeted test cases to cover edge scenarios based on
# model outputs.•
# Develop test cases to validate data quality, transformations, and
# reports. This may involve edge case testing, boundary value
# analysis, and other techniques to confirm data accuracy.•
# Led System Integration Testing (SIT) for the Crew Rostering
# Applications, including JCRS and ACTS, LASS, iMAPS.•
# Defined and maintained automation testing  for various software
# applications.•
# Validated database integrity and data accuracy through meticulous
# SQL scripting and database testing .•

# %% [markdown]
# > Note: While PDF files are great for laying out text in a way that’s easy for people to print and read, they’re `not straightforward` for software `to parse` into plaintext.
#
# > As such, `PyPDF2` might make mistakes when extracting text from a PDF and `may even be unable` to open some PDFs at all.
#
# > There `isn’t much we can do about this`, unfortunately. PyPDF2 may simply be unable to work with some of our particular PDF files.

# %%
# extract info
from PyPDF2 import PdfReader

pdf_path = r'pdf/ManaliMalkaniResume.pdf'

with open(pdf_path, 'rb') as f:
    pdf = PdfReader(f)
    
    metadata     = pdf.metadata
    print("Metadata:", metadata)

    # Get the number of pages (replaces getNumPages)
    number_of_pages = len(pdf.pages)
    print(f"Number of pages: {number_of_pages}")

    txt = f"""
    Information about {pdf_path}: 
    
    Author: {metadata.get('/Author', 'N/A')}
    Creator: {metadata.get('/Creator', 'N/A')}
    Producer: {metadata.get('/Producer', 'N/A')}
    Subject: {metadata.get('/Subject', 'N/A')}
    Title: {metadata.get('/Title', 'N/A')}
    Number of pages: {number_of_pages}
    """
    
    print(txt)
# Out:
# incorrect startxref pointer(3)
# Metadata: {'/HRJ_IDENTIFIER': 'f777ab18-f3f1-4f7b-bc8f-1e3fda7fd7a3', '/x1ye=': '...'}
# Number of pages: 2
#
#     Information about pdf/ManaliMalkaniResume.pdf:
#
#     Author: N/A
#     Creator: N/A
#     Producer: N/A
#     Subject: N/A
#     Title: N/A
#     Number of pages: 2

# %% [markdown]
# #### Rotate Pages
# - Occasionally, you will receive PDFs that contain pages that are in `landscape` mode instead of `portrait mode`.
# - Or perhaps they are even upside down.
#
# - This can happen when someone scans a document to PDF or email.

# %%
from PyPDF2 import PdfReader, PdfWriter

# Path to the PDF file
pdf_path = r'pdf/ManaliMalkaniResume.pdf'

# Open the PDF file for reading
with open(pdf_path, 'rb') as f:
    pdf_reader = PdfReader(f)
    
    # Create a PdfWriter object (replaces PdfFileWriter)
    pdf_writer = PdfWriter()
    
    # Rotate the first page 90 degrees to the right (example operation)
    first_page = pdf_reader.pages[0]
    first_page.rotate(90)  # Rotate by 90 degrees
    
    # Add the rotated page to the writer
    pdf_writer.add_page(first_page)
    
    # Write the modified PDF to a new file
    with open('rotated_pdf.pdf', 'wb') as output_file:
        pdf_writer.write(output_file)

    print("Page rotation complete. Modified PDF saved as 'rotated_pdf.pdf'.")
# Out:
# incorrect startxref pointer(3)
# Page rotation complete. Modified PDF saved as 'rotated_pdf.pdf'.

# %% [markdown]
# #### How to Add Watermarks
# - `Watermarks` are identifying images or patterns on printed and digital documents.
#
# - Some watermarks can only be seen in special lighting conditions. The reason watermarking is important is that it allows you to protect your intellectual property, such as your images or PDFs. Another term for `watermark is overlay`.

# %%
from PyPDF2 import PdfReader, PdfWriter

watermark  = r'pdf/watermark.pdf'
input_pdf  = r'pdf/ManaliMalkaniResume.pdf'
output_pdf = r'pdf/watermarked_pages.pdf'
 
# Open the PDF and watermark
with open(pdf_path, 'rb') as pdf_file, open(watermark, 'rb') as watermark_file:
    pdf_reader = PdfReader(pdf_file)
    watermark_reader = PdfReader(watermark_file)
    
    # Extract the watermark page
    watermark_page = watermark_reader.pages[0]
    
    # Create a writer object
    pdf_writer = PdfWriter()
    
    # Watermark all the pages
    for page in pdf_reader.pages:
        page.merge_page(watermark_page)
        pdf_writer.add_page(page)

# Save the watermarked PDF
    with open(output_pdf, 'wb') as output_file:
        pdf_writer.write(output_file)

print("Watermarking complete. Saved as 'watermarked_pdf.pdf'.")
# Out:
# incorrect startxref pointer(3)
# Watermarking complete. Saved as 'watermarked_pdf.pdf'.

# %%
from IPython.display import Image

# %% [markdown]
# ------------------------------
# ## Dictionary data structures
# -----------------------

# %% [markdown]
# - Python dictionary is an `unordered collection` of items.
#
# - Each item of a dictionary has a `key/value` pair.
#
# - Dictionaries are `optimized` to retrieve values when the `key` is known.

# %%
import os
print(os.getcwd())
# Out:
# /Users/mamalkani/Documents/AI and ML/Project/PythonCore

# %%
img = Image('/Users/mamalkani/Documents/AI and ML/Project/PythonCore/Images/dict_00.png', width=400)
display(img)

# %%
img1 = Image('/Users/mamalkani/Documents/AI and ML/Project/PythonCore/Images/dict_01.png', width=400)
display(img1)

# %% [markdown]
# A dictionary has the below syntax:
#
# {
#     key1: value1,
#     key2: value2,
#     .
#     .
#     .
#     keyN: valueN
# }

# %% [markdown]
# #### Creating Python Dictionary
# - placing items inside curly braces {} separated by commas.
#
# - An `item` has a `key` and a corresponding `value` that is expressed as a pair (`key: value`).
#
# - While the `values` can be of `any data type` and can repeat, `keys` must be of `immutable` type (string, number or tuple with immutable elements) and must be `unique`.

# %%
# empty dictionary
my_dict = {}
my_dict
# Out:
# {}

# %%
# dictionary with integer keys
my_dict = {1:'apple', 2:'ball'}
my_dict
# Out:
# {1: 'apple', 2: 'ball'}

# %%
# dictionary with mixed keys
my_dict = {'name': 'John', 1: [2,4,3]}
my_dict
# Out:
# {'name': 'John', 1: [2, 4, 3]}

# %%
# using dict()
my_dict = dict({1:'apple', 2:'ball'})
my_dict
# Out:
# {1: 'apple', 2: 'ball'}

# %%
# from sequence having each item as a pair
my_dict = dict([(1:'apple'), (2:'ball')])
my_dict
# Out:
#   Cell In[49], line 2
#     my_dict = dict([(1:'apple'), (2:'ball')])
#                       ^
# SyntaxError: invalid syntax
